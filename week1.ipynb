# %%
import pandas as pd

# %%
## Client 2: Lobbyists4America (Congressional Tweets Dataset -- 2008-2017 data)
# tweets = pd.read_json("tweets.json", lines=True)
# users = pd.read_json("users.json", lines=True)

# %%
## Client 3: SportsStats (Olympics Dataset - 120 years of data)
## SportsStats is a sports analysis firm partnering with local news and elite personal trainers to provide “interesting” insights 
## to help their partners.
## Insights could be patterns/trends highlighting certain groups/events/countries, etc. 
## for the purpose of developing a news story or discovering key health insights.

# %%
## Step 1: Preparing for Your Proposal

## You will document your preparation in developing the project proposal. This includes:

##    Which client/dataset did you select and why?

##    Describe the steps you took to import and clean the data.

##    Perform initial exploration of data and provide some screenshots or display some stats of the data you are looking at.

##    Create an ERD or proposed ERD to show the relationships of the data you are exploring.

# %%
# #### Step 1

# <!-- Which client/dataset did you select and why? -->

# Olympic Dataset, because I have an inclination in sports and would like to make a career out of it. Using this dataset I can create a great project that can shine in my resume and plus sports is a field which I really like

# <!-- Describe the steps you took to import and clean the data. -->

# I used Pandas library for reading the data, which is in csv file. To clean the data, first I removed the null values and merge the two dataframe based on the NOC columns.

# <!-- Perform initial exploration of data and provide some screenshots or display some stats of the data you are looking at. -->

# df.describe()
# df.info()
# merge two df_events and df_regions

# <!-- Create an ERD or proposed ERD to show the relationships of the data you are exploring.  -->

# %%
## Step 2: Develop Project Proposal | In this step, you will need to include the following:

## 1. Description
## Write a 5-6 sentence paragraph describing your project; include who might be interested to learn about your findings. Who might be your audience?



## 2. Questions
## Create 2-3 questions that you want to answer with the data:



## 3. Hypothesis
## What are your initial hypotheses about the data?
## Write 2-3 assumptions about the data that you'll want to go back to prove or disprove. You will want to keep them in front of you as you look at the data to keep them or change them. You may see relationships that you want to explore and will develop a "belief" about the data.  
##    Start documenting what you think you can tell from the data. 
##    What pops up as interesting to you? Most likely it will be interesting to others as well.
##    Use the discussion boards to discuss with others about your client and the data to brainstorm together.


## 4. Approach
## Describe in 5-6 sentences what approach you are going to take in order to prove (or disprove) your hypotheses. Think about the following in your answer:  
##    What features (fields/columns) are you going to look at first?
##    Is there a relationship that exists that you want to explore?
##    What metric/ evaluation measure will you use?

# %%
df_athlete_events = pd.read_csv("data/athlete_events.csv")
df_noc_regions = pd.read_csv("data/noc_regions.csv")

# %%
df_athlete_events.head()

# %%
df_noc_regions.head() # NOC :  National Olympic Committee (3-letter code)
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
df_final = pd.merge(df_athlete_events,df_noc_regions,'inner',on='NOC')
df_final.head()
# Out:
#      ID           Name Sex   Age  Height  Weight   Team  NOC        Games
# 0     1      A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer  \
# 1     2       A Lamusi   M  23.0   170.0    60.0  China  CHN  2012 Summer
# 2   602  Abudoureheman   M  22.0   182.0    75.0  China  CHN  2000 Summer
# 3  1463      Ai Linuer   M  25.0   160.0    62.0  China  CHN  2004 Summer
# 4  1464      Ai Yanhan   F  14.0   168.0    54.0  China  CHN  2016 Summer
#
#    Year  Season            City       Sport
# 0  1992  Summer       Barcelona  Basketball  \
# 1  2012  Summer          London        Judo
# 2  2000  Summer          Sydney      Boxing
# 3  2004  Summer          Athina   Wrestling
# 4  2016  Summer  Rio de Janeiro    Swimming
#
#                                       Event Medal region notes
# 0               Basketball Men's Basketball   NaN  China   NaN
# 1              Judo Men's Extra-Lightweight   NaN  China   NaN
# 2                 Boxing Men's Middleweight   NaN  China   NaN
# 3  Wrestling Men's Lightweight, Greco-Roman   NaN  China   NaN
# 4     Swimming Women's 200 metres Freestyle   NaN  China   NaN

# %%
info = [df_final['Season'].unique(),
        df_final['Team'].unique(),
        df_final['Sport'].unique(),
        df_final['Event'].unique(),
        df_final['region'].unique(),
        df_final['Medal'].unique()]

for i in info:
    print(i,len(i),sep=" | ")
    print("---------------")
    print()
# Out:
# ['Summer' 'Winter'] | 2
# ---------------
#
# ['China' 'China-2' 'China-1' ... 'Kosovo' 'South Sudan' 'Lesotho'] | 1179
# ---------------
#
# ['Basketball' 'Judo' 'Boxing' 'Wrestling' 'Swimming' 'Speed Skating'
#  'Short Track Speed Skating' 'Softball' 'Hockey' 'Curling' 'Archery'
#  'Triathlon' 'Football' 'Rhythmic Gymnastics' 'Athletics' 'Badminton'
#  'Fencing' 'Figure Skating' 'Gymnastics' 'Volleyball' 'Baseball'
#  'Water Polo' 'Snowboarding' 'Shooting' 'Weightlifting' 'Cycling' 'Rowing'
#  'Sailing' 'Diving' 'Modern Pentathlon' 'Art Competitions'
#  'Synchronized Swimming' 'Handball' 'Canoeing' 'Cross Country Skiing'
#  'Table Tennis' 'Ice Hockey' 'Tennis' 'Taekwondo' 'Freestyle Skiing'
#  'Beach Volleyball' 'Trampolining' 'Alpine Skiing' 'Golf' 'Biathlon'
#  'Equestrianism' 'Ski Jumping' 'Tug-Of-War' 'Bobsleigh' 'Nordic Combined'
#  'Polo' 'Skeleton' 'Rugby Sevens' 'Luge' 'Roque' 'Rugby' 'Lacrosse'
#  'Jeu De Paume' 'Military Ski Patrol' 'Cricket' 'Croquet' 'Motorboating'
#  'Basque Pelota' 'Alpinism' 'Aeronautics' 'Racquets'] | 66
# ---------------
#
# ["Basketball Men's Basketball" "Judo Men's Extra-Lightweight"
#  "Boxing Men's Middleweight" "Wrestling Men's Lightweight, Greco-Roman"
#  "Swimming Women's 200 metres Freestyle"
#  "Swimming Women's 4 x 200 metres Freestyle Relay"
#  "Speed Skating Men's 500 metres" "Speed Skating Men's 1,000 metres"
#  "Short Track Speed Skating Men's 500 metres"
#  "Short Track Speed Skating Men's 1,000 metres"
#  "Short Track Speed Skating Men's 5,000 metres Relay"
#  "Softball Women's Softball" "Hockey Men's Hockey"
#  "Judo Men's Middleweight" "Curling Men's Curling"
#  "Basketball Women's Basketball"
#  "Wrestling Men's Heavyweight, Greco-Roman" "Archery Men's Individual"
#  "Swimming Women's 200 metres Backstroke" "Boxing Men's Light-Heavyweight"
#  "Triathlon Men's Olympic Distance" "Football Women's Football"
#  "Rhythmic Gymnastics Women's Individual"
#  "Athletics Women's 10,000 metres" "Badminton Men's Singles"
#  "Football Men's Football" "Fencing Women's Sabre, Individual"
#  "Fencing Women's Sabre, Team" "Rhythmic Gymnastics Women's Group"
#  "Figure Skating Women's Singles"
#  "Wrestling Men's Light-Heavyweight, Freestyle"
#  "Gymnastics Women's Individual All-Around"
#  "Gymnastics Women's Team All-Around" "Gymnastics Women's Horse Vault"
#  "Gymnastics Women's Uneven Bars" "Gymnastics Women's Balance Beam"
#  "Athletics Men's Hammer Throw" "Volleyball Men's Volleyball"
#  "Athletics Women's Shot Put" "Athletics Women's 400 metres"
#  "Baseball Men's Baseball" "Swimming Women's 100 metres Butterfly"
#  "Swimming Women's 4 x 100 metres Medley Relay"
#  "Athletics Men's 100 metres" "Athletics Men's 4 x 100 metres Relay"
#  "Swimming Men's 50 metres Freestyle"
#  "Swimming Men's 4 x 100 metres Freestyle Relay"
#  "Athletics Men's Marathon" "Water Polo Men's Water Polo"
#  "Athletics Men's High Jump" "Athletics Men's 50 kilometres Walk"
#  "Hockey Women's Hockey" "Snowboarding Women's Halfpipe"
#  "Shooting Men's Air Rifle, 10 metres"
#  "Shooting Men's Small-Bore Rifle, Three Positions, 50 metres"
#  "Weightlifting Men's Middleweight"
#  "Weightlifting Men's Light-Heavyweight"
#  "Shooting Women's Sporting Pistol, 25 metres"
#  "Cycling Men's Road Race, Individual" "Badminton Men's Doubles"
#  "Athletics Men's 20 kilometres Walk" "Speed Skating Women's 500 metres"
#  "Speed Skating Women's 1,000 metres" "Archery Women's Individual"
#  "Archery Women's Team" "Weightlifting Women's Heavyweight"
#  "Rowing Women's Double Sculls" "Rowing Women's Coxless Fours"
#  "Rowing Women's Coxed Eights" "Rowing Women's Quadruple Sculls"
#  "Athletics Women's Discus Throw" "Athletics Men's Triple Jump"
#  'Figure Skating Mixed Ice Dancing' 'Sailing Mixed One Person Dinghy'
#  "Shooting Men's Small-Bore Rifle, Prone, 50 metres"
#  "Diving Men's Synchronized Platform" "Diving Men's Springboard"
#  "Diving Men's Synchronized Springboard"
#  "Swimming Women's 400 metres Freestyle"
#  "Modern Pentathlon Men's Individual"
#  "Swimming Men's 100 metres Freestyle"
#  'Art Competitions Mixed Painting, Paintings'
#  "Athletics Women's Javelin Throw"
#  "Swimming Men's 200 metres Breaststroke"
#  "Synchronized Swimming Women's Team" "Athletics Men's Decathlon"
#  "Wrestling Men's Middleweight, Greco-Roman"
#  "Swimming Women's 4 x 100 metres Freestyle Relay"
#  "Handball Women's Handball" "Diving Men's Platform"
#  "Athletics Men's Shot Put" "Fencing Men's Foil, Team"
#  "Rowing Women's Coxed Fours" "Gymnastics Women's Floor Exercise"
#  "Short Track Speed Skating Men's 1,500 metres" "Shooting Men's Skeet"
#  "Shooting Women's Trap" "Judo Women's Middleweight"
#  "Fencing Men's Sabre, Individual" "Fencing Men's Sabre, Team"
#  "Volleyball Women's Volleyball" "Canoeing Men's Canadian Doubles, Slalom"
#  "Cross Country Skiing Men's Sprint" "Fencing Men's Foil, Individual"
#  'Art Competitions Mixed Painting, Graphic Arts'
#  "Swimming Women's 800 metres Freestyle"
#  "Swimming Women's 100 metres Breaststroke"
#  "Swimming Women's 200 metres Breaststroke"
#  "Swimming Men's 100 metres Breaststroke"
#  "Swimming Men's 4 x 100 metres Medley Relay"
#  "Table Tennis Women's Singles" "Table Tennis Women's Doubles"
#  "Athletics Men's Long Jump" "Ice Hockey Women's Ice Hockey"
#  "Athletics Women's 4 x 400 metres Relay"
#  "Fencing Women's Foil, Individual" "Athletics Men's 200 metres"
#  "Tennis Women's Singles" "Tennis Women's Doubles"
#  "Weightlifting Men's Featherweight" 'Badminton Mixed Doubles'
#  "Table Tennis Men's Singles" "Table Tennis Men's Doubles"
#  "Shooting Women's Air Rifle, 10 metres"
#  "Shooting Women's Small-Bore Rifle, Three Positions, 50 metres"
#  "Sailing Women's Windsurfer" "Athletics Men's Javelin Throw"
#  "Modern Pentathlon Women's Individual"
#  "Swimming Men's 200 metres Individual Medley"
#  "Athletics Women's 3,000 metres" "Sailing Women's Two Person Dinghy"
#  "Diving Women's Platform" "Diving Women's Synchronized Platform"
#  "Speed Skating Women's 1,500 metres" "Boxing Men's Lightweight"
#  "Cycling Women's Road Race, Individual"
#  "Weightlifting Women's Middleweight" "Weightlifting Women's Flyweight"
#  "Wrestling Men's Super-Heavyweight, Freestyle" 'Sailing Mixed Multihull'
#  "Swimming Women's 400 metres Individual Medley"
#  "Swimming Women's 200 metres Individual Medley"
#  "Swimming Women's 100 metres Backstroke"
#  "Athletics Men's 110 metres Hurdles" "Weightlifting Women's Lightweight"
#  "Gymnastics Men's Individual All-Around"
#  "Gymnastics Men's Team All-Around" "Gymnastics Men's Floor Exercise"
#  "Gymnastics Men's Parallel Bars" "Gymnastics Men's Horizontal Bar"
#  "Gymnastics Men's Rings" "Gymnastics Men's Pommelled Horse"
#  "Swimming Men's 200 metres Butterfly" "Badminton Women's Doubles"
#  "Athletics Men's 400 metres" "Wrestling Men's Bantamweight, Freestyle"
#  "Shooting Men's Rapid-Fire Pistol, 25 metres"
#  "Athletics Women's 10 kilometres Walk"
#  "Cross Country Skiing Women's 5 kilometres"
#  "Cross Country Skiing Women's 10 kilometres"
#  "Cross Country Skiing Women's 4 x 5 kilometres Relay"
#  "Athletics Women's 200 metres" "Athletics Women's 4 x 100 metres Relay"
#  "Wrestling Men's Light-Flyweight, Freestyle"
#  "Taekwondo Women's Heavyweight"
#  "Canoeing Men's Canadian Doubles, 1,000 metres"
#  "Swimming Men's 4 x 200 metres Freestyle Relay"
#  "Cycling Men's Team Sprint" "Swimming Men's 100 metres Backstroke"
#  "Swimming Women's 100 metres Freestyle"
#  "Freestyle Skiing Women's Aerials" "Athletics Men's 400 metres Hurdles"
#  "Short Track Speed Skating Women's 1,500 metres"
#  "Short Track Speed Skating Women's 3,000 metres Relay"
#  "Beach Volleyball Women's Beach Volleyball"
#  "Canoeing Men's Kayak Doubles, 1,000 metres"
#  "Rowing Women's Coxless Pairs" "Handball Men's Handball"
#  "Weightlifting Men's Heavyweight II" "Fencing Men's epee, Individual"
#  "Fencing Men's epee, Team" "Swimming Men's 1,500 metres Freestyle"
#  "Archery Men's Team" "Badminton Women's Singles"
#  "Sailing Men's Two Person Dinghy" "Swimming Men's 200 metres Backstroke"
#  "Canoeing Men's Kayak Singles, Slalom"
#  "Weightlifting Women's Super-Heavyweight" "Table Tennis Women's Team"
#  "Boxing Women's Lightweight" "Trampolining Men's Individual"
#  "Alpine Skiing Women's Giant Slalom" "Alpine Skiing Women's Slalom"
#  "Canoeing Women's Kayak Fours, 500 metres" "Athletics Women's Heptathlon"
#  "Athletics Men's 1,500 metres" "Athletics Women's 100 metres Hurdles"
#  "Shooting Men's Trap" "Rowing Women's Single Sculls"
#  "Athletics Men's 800 metres" "Fencing Women's Foil, Team"
#  "Gymnastics Men's Horse Vault"
#  "Short Track Speed Skating Women's 500 metres"
#  "Short Track Speed Skating Women's 1,000 metres"
#  "Cycling Men's Team Pursuit, 4,000 metres"
#  "Swimming Women's 10 kilometres Open Water" "Rowing Men's Coxed Fours"
#  "Rowing Men's Coxed Eights" "Canoeing Men's Canadian Singles, Slalom"
#  "Speed Skating Men's 1,500 metres" "Golf Women's Individual"
#  "Cycling Men's Keirin" "Athletics Men's Pole Vault"
#  "Speed Skating Women's 3,000 metres" "Diving Women's Springboard"
#  "Diving Women's Synchronized Springboard" "Water Polo Women's Water Polo"
#  "Canoeing Women's Kayak Singles, 500 metres" 'Shooting Mixed Trap'
#  "Shooting Women's Double Trap" "Judo Men's Half-Lightweight"
#  "Judo Women's Extra-Lightweight" "Athletics Women's 100 metres"
#  "Cycling Women's Mountainbike, Cross-Country"
#  "Canoeing Men's Kayak Doubles, 500 metres"
#  "Cycling Women's Individual Time Trial" "Athletics Women's Pole Vault"
#  "Speed Skating Men's 5,000 metres" "Athletics Women's High Jump"
#  "Shooting Men's Running Target, 10 metres"
#  "Cross Country Skiing Women's 15 kilometres"
#  "Cross Country Skiing Women's 30 kilometres"
#  "Cross Country Skiing Women's 5/10 kilometres Pursuit"
#  "Cycling Women's Team Sprint" "Cycling Women's Sprint"
#  "Cycling Women's Keirin" "Sailing Men's One Person Heavyweight Dinghy"
#  "Synchronized Swimming Women's Duet" "Rowing Men's Coxless Fours"
#  "Boxing Men's Bantamweight" "Athletics Women's Hammer Throw"
#  "Athletics Women's Long Jump" "Synchronized Swimming Women's Solo"
#  "Canoeing Men's Canadian Doubles, 500 metres"
#  "Athletics Men's Discus Throw" "Judo Men's Half-Middleweight"
#  "Cycling Men's 100 kilometres Team Time Trial"
#  "Shooting Women's Air Pistol, 10 metres" "Figure Skating Men's Singles"
#  "Cross Country Skiing Men's 15 kilometres"
#  "Cross Country Skiing Men's 30 kilometres"
#  "Cross Country Skiing Men's 50 kilometres"
#  "Cross Country Skiing Men's 10/10 kilometres Pursuit"
#  "Cross Country Skiing Men's 30 km Skiathlon"
#  "Biathlon Men's 10 kilometres Sprint" "Freestyle Skiing Men's Aerials"
#  "Swimming Women's 50 metres Freestyle" "Boxing Men's Welterweight"
#  "Fencing Women's epee, Team" "Swimming Men's 400 metres Freestyle"
#  "Judo Women's Half-Lightweight" "Taekwondo Women's Welterweight"
#  "Trampolining Women's Individual" "Weightlifting Men's Bantamweight"
#  "Weightlifting Men's Flyweight" "Wrestling Men's Lightweight, Freestyle"
#  "Wrestling Men's Welterweight, Freestyle"
#  "Cross Country Skiing Women's Sprint"
#  "Cross Country Skiing Women's 5/5 kilometres Pursuit"
#  "Biathlon Women's 7.5 kilometres Sprint"
#  "Biathlon Women's 12.5 kilometres Mass Start"
#  "Biathlon Women's 15 kilometres" "Taekwondo Women's Featherweight"
#  "Shooting Men's Double Trap" "Canoeing Women's Kayak Doubles, 500 metres"
#  "Wrestling Men's Featherweight, Greco-Roman" "Boxing Men's Flyweight"
#  "Boxing Men's Light-Welterweight"
#  "Wrestling Men's Flyweight, Greco-Roman" 'Sailing Mixed Skiff'
#  "Rowing Men's Double Sculls" "Rowing Men's Quadruple Sculls"
#  "Athletics Women's Marathon"
#  'Equestrianism Mixed Three-Day Event, Individual'
#  "Cycling Women's Team Pursuit" "Cycling Women's Omnium"
#  "Athletics Women's Triple Jump"
#  "Shooting Men's Running Target, 50 metres"
#  "Rowing Women's Lightweight Double Sculls"
#  "Athletics Women's 400 metres Hurdles" 'Figure Skating Mixed Team'
#  "Rowing Men's Lightweight Coxless Fours"
#  "Canoeing Men's Kayak Fours, 1,000 metres"
#  'Equestrianism Mixed Jumping, Individual'
#  'Equestrianism Mixed Jumping, Team'
#  "Speed Skating Women's Team Pursuit (6 laps)"
#  "Cycling Men's Mountainbike, Cross-Country" 'Sailing Mixed Windsurfer'
#  "Sailing Men's Windsurfer" "Swimming Men's 100 metres Butterfly"
#  "Cross Country Skiing Women's Team Sprint"
#  "Cycling Women's 500 metres Time Trial"
#  "Athletics Women's 20 kilometres Walk" "Boxing Men's Heavyweight"
#  "Wrestling Men's Light-Flyweight, Greco-Roman"
#  "Swimming Women's 200 metres Butterfly"
#  "Swimming Men's 400 metres Individual Medley" "Judo Women's Lightweight"
#  "Wrestling Women's Middleweight, Freestyle"
#  "Canoeing Men's Canadian Singles, 1,000 metres"
#  "Biathlon Women's 4 x 7.5 kilometres Relay"
#  "Biathlon Women's 10 kilometres Pursuit"
#  "Biathlon Women's 4 x 6 kilometres Relay" "Judo Women's Half-Heavyweight"
#  "Cross Country Skiing Men's 4 x 10 kilometres Relay"
#  "Cross Country Skiing Men's Team Sprint"
#  "Alpine Skiing Men's Giant Slalom" "Alpine Skiing Men's Slalom"
#  "Golf Men's Individual" "Sailing Men's Two Person Keelboat"
#  "Cross Country Skiing Women's 15 km Skiathlon"
#  "Wrestling Women's Flyweight, Freestyle"
#  "Canoeing Women's Kayak Singles, Slalom"
#  "Weightlifting Men's Lightweight" "Boxing Women's Middleweight"
#  "Cycling Women's Points Race" "Fencing Women's epee, Individual"
#  "Canoeing Men's Canadian Singles, 500 metres"
#  "Canoeing Men's Canadian Singles, 200 metres"
#  "Judo Women's Half-Middleweight" 'Figure Skating Mixed Pairs'
#  "Cycling Men's Points Race" "Wrestling Men's Featherweight, Freestyle"
#  "Biathlon Men's 4 x 7.5 kilometres Relay"
#  "Sailing Women's Three Person Keelboat" "Alpine Skiing Women's Super G"
#  "Weightlifting Women's Featherweight" "Boxing Men's Featherweight"
#  "Ski Jumping Men's Normal Hill, Individual"
#  "Ski Jumping Men's Large Hill, Individual"
#  "Ski Jumping Men's Large Hill, Team"
#  "Wrestling Men's Welterweight, Greco-Roman"
#  "Swimming Men's 200 metres Freestyle"
#  "Athletics Women's 3,000 metres Steeplechase"
#  "Wrestling Men's Flyweight, Freestyle"
#  "Weightlifting Women's Light-Heavyweight"
#  "Shooting Men's Free Pistol, 50 metres" "Judo Men's Half-Heavyweight"
#  "Wrestling Men's Super-Heavyweight, Greco-Roman"
#  "Biathlon Women's 3 x 7.5 kilometres Relay"
#  "Canoeing Men's Kayak Singles, 500 metres"
#  "Canoeing Men's Kayak Singles, 1,000 metres"
#  "Biathlon Men's 20 kilometres" "Speed Skating Women's 5,000 metres"
#  "Athletics Women's 1,500 metres"
#  'Equestrianism Mixed Dressage, Individual' "Judo Men's Heavyweight"
#  "Tennis Men's Doubles" "Taekwondo Men's Heavyweight"
#  "Curling Women's Curling" "Boxing Men's Light-Flyweight"
#  "Speed Skating Men's 10,000 metres" "Athletics Men's 5,000 metres"
#  "Athletics Men's 10,000 metres" "Table Tennis Men's Team"
#  "Cycling Women's BMX" "Wrestling Men's Light-Heavyweight, Greco-Roman"
#  "Weightlifting Men's Middle-Heavyweight"
#  "Freestyle Skiing Women's Moguls" "Shooting Men's Air Pistol, 10 metres"
#  "Cross Country Skiing Men's 10 kilometres" "Boxing Women's Flyweight"
#  "Judo Men's Lightweight" "Sailing Men's One Person Dinghy"
#  "Sailing Women's One Person Dinghy"
#  "Wrestling Men's Bantamweight, Greco-Roman"
#  "Triathlon Women's Olympic Distance" "Snowboarding Men's Halfpipe"
#  "Wrestling Men's Middleweight, Freestyle" "Rowing Men's Single Sculls"
#  "Wrestling Women's Lightweight, Freestyle" "Judo Women's Heavyweight"
#  "Rowing Men's Lightweight Double Sculls" "Tennis Men's Singles"
#  "Athletics Women's 5,000 metres"
#  "Cross Country Skiing Women's 20 kilometres"
#  "Athletics Women's 800 metres" "Wrestling Women's Heavyweight, Freestyle"
#  "Cycling Women's Individual Pursuit, 3,000 metres"
#  "Wrestling Men's Heavyweight, Freestyle" 'Shooting Mixed Skeet'
#  "Shooting Women's Skeet" "Cycling Men's Sprint"
#  "Taekwondo Women's Flyweight"
#  "Cross Country Skiing Men's 10/15 kilometres Pursuit"
#  "Beach Volleyball Men's Beach Volleyball"
#  "Swimming Men's 10 kilometres Open Water" "Judo Men's Open Class"
#  'Sailing Mixed Two Person Dinghy' "Weightlifting Men's Heavyweight"
#  'Art Competitions Mixed Painting, Unknown Event'
#  "Biathlon Men's 12.5 kilometres Pursuit" "Boxing Men's Super-Heavyweight"
#  "Taekwondo Men's Flyweight" "Wrestling Women's Featherweight, Freestyle"
#  "Wrestling Women's Light-Heavyweight, Freestyle"
#  "Canoeing Women's Kayak Singles, 200 metres"
#  "Canoeing Men's Kayak Singles, 200 metres" "Taekwondo Men's Welterweight"
#  "Tug-Of-War Men's Tug-Of-War" "Equestrianism Men's Jumping, Individual"
#  "Equestrianism Men's Jumping, Team"
#  "Equestrianism Men's Three-Day Event, Individual"
#  "Equestrianism Men's Three-Day Event, Team"
#  "Gymnastics Men's Team All-Around, Free System"
#  "Alpine Skiing Men's Downhill" "Alpine Skiing Men's Super G"
#  "Rowing Men's Coxed Fours, Inriggers"
#  "Athletics Men's Cross-Country, Individual"
#  "Athletics Men's Cross-Country, Team"
#  "Wrestling Men's Middleweight A, Greco-Roman"
#  "Shooting Men's Free Rifle, Three Positions, 300 metres"
#  "Shooting Men's Free Rifle, Three Positions, 300 metres, Team"
#  "Shooting Men's Military Rifle, Prone, 300 metres"
#  "Shooting Men's Military Rifle, Prone, 300 metres, Team"
#  'Sailing Mixed Two Person Keelboat' "Rowing Men's Coxed Pairs"
#  "Shooting Men's Free Pistol, 50 metres, Team"
#  "Cycling Men's Tandem Sprint, 2,000 metres"
#  'Sailing Mixed Three Person Keelboat' 'Art Competitions Mixed Painting'
#  "Rowing Women's Coxed Quadruple Sculls" "Cycling Men's Road Race, Team"
#  "Shooting Men's Military Rifle, 200/500/600/800/900/1,000 Yards, Team"
#  "Shooting Men's Military Rifle, 200, 400, 500 and 600 metres, Team"
#  "Gymnastics Men's Team All-Around, Swedish System"
#  'Shooting Mixed Free Rifle, Three Positions, 300 metres'
#  'Shooting Mixed Small-Bore Rifle, Prone, 50 metres'
#  "Cycling Men's 20 kilometres" "Cycling Men's Individual Time Trial"
#  "Cycling Men's BMX" "Rowing Men's Coxed Pairs (1 kilometres)"
#  'Sailing Mixed 8 metres' 'Sailing Mixed 5.5 metres'
#  "Fencing Men's Foil, Masters, Individual"
#  "Rowing Men's Coxed Fours, Outriggers" "Boxing Men's Light-Middleweight"
#  'Sailing Mixed Two Person Heavyweight Dinghy'
#  'Art Competitions Mixed Sculpturing, Unknown Event'
#  "Rowing Men's Coxless Pairs" 'Art Competitions Mixed Music'
#  'Art Competitions Mixed Literature' 'Tennis Mixed Doubles'
#  'Art Competitions Mixed Music, Compositions For Orchestra'
#  "Alpine Skiing Men's Combined" 'Art Competitions Mixed Architecture'
#  'Tennis Mixed Doubles, Covered Courts'
#  "Tennis Women's Singles, Covered Courts"
#  'Equestrianism Mixed Dressage, Team'
#  "Canoeing Men's Kayak Doubles, 10,000 metres"
#  "Wrestling Men's Middleweight B, Greco-Roman"
#  "Cycling Men's 1,000 metres Time Trial"
#  'Shooting Mixed Rapid-Fire Pistol, 25 metres' 'Sailing Mixed 6 metres'
#  'Shooting Mixed Small-Bore Rifle, Three Positions, 50 metres'
#  "Cycling Men's Individual Pursuit, 4,000 metres"
#  "Diving Women's Plain High" 'Shooting Mixed Free Pistol, 50 metres'
#  "Shooting Men's Small-Bore Rifle, Prone, 50 metres, Team"
#  "Canoeing Men's Kayak Singles, 10,000 metres"
#  "Canoeing Men's Canadian Doubles, 10,000 metres"
#  "Freestyle Skiing Women's Ski Cross"
#  "Equestrianism Men's Dressage, Individual"
#  "Shooting Men's Military Rifle, Any Position, 600 metres"
#  'Art Competitions Mixed Sculpturing'
#  "Shooting Men's Military Rifle, Three Positions, 300 metres"
#  "Shooting Men's Small-Bore Rifle, Any Position, 50 metres"
#  "Shooting Men's Small-Bore Rifle, Disappearing Target, 25 metres"
#  "Shooting Men's Military Rifle, Prone, 600 metres"
#  'Art Competitions Mixed Sculpturing, Statues'
#  "Athletics Men's 10 kilometres Walk" "Cycling Men's 50 kilometres"
#  "Canoeing Men's Kayak Relay 4 x 500 metres" "Sailing Women's Skiff"
#  "Cycling Men's Omnium" "Athletics Women's Pentathlon"
#  "Modern Pentathlon Men's Team"
#  'Art Competitions Mixed Literature, Lyric Works'
#  "Athletics Men's 3,000 metres Steeplechase"
#  'Art Competitions Mixed Architecture, Designs For Town Planning'
#  'Art Competitions Mixed Architecture, Architectural Designs'
#  "Athletics Men's 3,500 metres Walk" "Athletics Men's 10 mile Walk"
#  "Diving Men's Plain High" "Wrestling Men's All-Around, Greco-Roman"
#  "Weightlifting Men's Unlimited, One Hand"
#  "Weightlifting Men's Unlimited, Two Hands"
#  "Gymnastics Men's Rope Climbing"
#  "Shooting Men's Military Rifle, 200 metres"
#  "Shooting Men's Free Rifle, Kneeling, 300 metres"
#  "Shooting Men's Free Rifle, Prone, 300 metres"
#  "Shooting Men's Free Rifle, Standing, 300 metres"
#  "Athletics Men's 5 mile" "Snowboarding Men's Giant Slalom"
#  "Sailing Men's Skiff" "Athletics Men's Standing High Jump"
#  "Athletics Men's Standing Long Jump"
#  "Tennis Men's Singles, Covered Courts"
#  "Shooting Men's Military Rifle, Standing, 300 metres"
#  "Shooting Men's Military Rifle, Standing, 300 metres, Team"
#  "Shooting Men's Free Rifle, Prone, 600 metres"
#  "Shooting Men's Free Rifle, 400, 600 and 800 metres, Team"
#  "Snowboarding Women's Boardercross" "Swimming Men's Underwater Swimming"
#  "Cycling Men's Madison"
#  "Shooting Men's Small-Bore Rifle, Standing, 50 metres"
#  "Shooting Men's Small Bore-Rifle, Standing, 50 metres, Team"
#  "Shooting Men's Free Pistol, 30 metres"
#  "Shooting Men's Military Pistol, 25 metres"
#  "Shooting Men's Muzzle-Loading Pistol, 25 metres"
#  'Art Competitions Mixed Literature, Epic Works'
#  "Rowing Men's Coxed Pairs (1 mile)" "Weightlifting Men's Heavyweight I"
#  "Athletics Men's 3,000 metres Walk" "Taekwondo Men's Featherweight"
#  'Art Competitions Mixed Architecture, Unknown Event'
#  "Swimming Men's One Mile Freestyle"
#  'Art Competitions Mixed Music, Compositions For Solo Or Chorus'
#  "Bobsleigh Men's Four" "Ice Hockey Men's Ice Hockey"
#  'Sailing Mixed 12 foot' "Athletics Women's 80 metres Hurdles"
#  "Speed Skating Men's Team Pursuit (8 laps)"
#  'Equestrianism Mixed Three-Day Event, Team'
#  'Art Competitions Mixed Painting, Drawings And Water Colors'
#  'Art Competitions Mixed Sculpturing, Medals And Reliefs'
#  "Cycling Men's Team Pursuit, 1,980 yards" "Cycling Men's 5,000 metres"
#  "Cycling Men's 100 kilometres"
#  "Shooting Men's Military Rifle, Prone, 600 metres, Team"
#  "Shooting Men's Military Rifle, 300 metres and 600 metres, Prone, Team"
#  "Athletics Men's 3 mile, Team" "Bobsleigh Women's Two"
#  "Athletics Men's 4 x 400 metres Relay"
#  "Shooting Men's Free Pistol, 50 yards"
#  "Equestrianism Men's Dressage, Team" 'Sailing Mixed 6.5 metres'
#  "Gymnastics Women's Team Portable Apparatus"
#  "Shooting Men's Free Pistol, 50 yards, Team"
#  "Archery Men's Target Archery, 28 metres, Team"
#  "Shooting Men's Trap, Team" "Fencing Men's Sabre, Individual, Three Hits"
#  "Athletics Men's Pentathlon" "Bobsleigh Men's Two"
#  "Snowboarding Women's Parallel Giant Slalom"
#  "Snowboarding Women's Parallel Slalom" "Bobsleigh Men's Four/Five"
#  "Athletics Men's 1,600 metres Medley Relay" "Archery Men's Unknown Event"
#  'Sailing Mixed Open' 'Sailing Mixed 3-10 Ton'
#  "Snowboarding Women's Slopestyle" "Swimming Men's 4,000 metres Freestyle"
#  'Art Competitions Mixed Painting, Applied Arts'
#  "Shooting Men's Unknown Event" "Alpine Skiing Women's Combined"
#  "Fencing Men's epee, Masters, Individual"
#  'Art Competitions Mixed Literature, Dramatic Works'
#  "Canoeing Men's Folding Kayak Singles, 10 kilometres"
#  "Canoeing Men's Folding Kayak Doubles, 10 kilometres"
#  "Swimming Men's 220 yard Freestyle" "Swimming Men's 880 yard Freestyle"
#  "Swimming Men's 4 x 50 Yard Freestyle Relay"
#  "Swimming Men's Plunge For Distance"
#  "Athletics Men's Discus Throw, Greek Style"
#  "Nordic Combined Men's Individual" "Freestyle Skiing Men's Moguls"
#  "Polo Men's Polo" "Gymnastics Men's Individual All-Around, Field Sports"
#  "Gymnastics Men's Individual All-Around, Apparatus Work"
#  "Cross Country Skiing Men's 18 kilometres" "Cycling Men's 1/4 mile"
#  "Cycling Men's 1/2 mile" "Cycling Men's 5 mile" "Cycling Men's 25 mile"
#  "Skeleton Men's Skeleton" "Alpine Skiing Women's Downhill"
#  'Biathlon Mixed 2 x 6 kilometres and 2 x 7.5 kilometres Relay'
#  "Biathlon Men's 15 kilometres Mass Start"
#  "Rugby Sevens Men's Rugby Sevens" "Rugby Sevens Women's Rugby Sevens"
#  "Luge Mixed (Men)'s Doubles" "Snowboarding Men's Boardercross"
#  "Athletics Men's Standing Triple Jump"
#  "Shooting Men's Military Pistol, 30 metres"
#  "Shooting Men's Free Rifle, 1,000 Yards" "Luge Men's Singles"
#  "Weightlifting Men's Super-Heavyweight"
#  "Athletics Men's 3,000 metres, Team" "Cycling Men's 1/3 mile"
#  "Cycling Men's 1 mile" "Cycling Men's 2 mile" "Athletics Men's 60 metres"
#  "Swimming Women's 300 metres Freestyle" "Freestyle Skiing Men's Halfpipe"
#  "Shooting Men's Running Target, Single Shot"
#  "Shooting Men's Running Target, Single Shot, Team"
#  "Shooting Men's Running Target, Double Shot"
#  "Shooting Men's Running Target, Double Shot, Team"
#  "Athletics Men's 1,500 metres Walk"
#  "Athletics Men's 3,200 metres Steeplechase"
#  "Swimming Men's 4 x 250 metres Freestyle Relay"
#  "Freestyle Skiing Women's Halfpipe"
#  "Cross Country Skiing Women's 3 x 5 kilometres Relay"
#  "Luge Women's Singles" "Freestyle Skiing Men's Slopestyle"
#  "Roque Men's Singles" "Archery Men's Double American Round"
#  "Archery Men's Double York Round" "Archery Men's Team Round"
#  'Art Competitions Mixed Literature, Unknown Event'
#  "Athletics Men's Discus Throw, Both Hands" "Golf Men's Team"
#  "Nordic Combined Men's Normal Hill / 10 km, Individual"
#  "Nordic Combined Men's Team" "Nordic Combined Men's Sprint"
#  "Rugby Men's Rugby" "Athletics Men's 200 metres Hurdles"
#  "Athletics Men's 56-pound Weight Throw"
#  "Athletics Men's All-Around Championship"
#  "Athletics Men's 2,590 metres Steeplechase"
#  "Archery Women's Double Columbia Round"
#  "Archery Women's Double National Round"
#  "Swimming Men's 50 yard Freestyle" "Swimming Men's 100 yard Freestyle"
#  "Swimming Men's 440 yard Freestyle"
#  'Shooting Mixed Running Target, 50 metres'
#  "Nordic Combined Men's Large Hill / 10 km, Individual"
#  "Shooting Men's Dueling Pistol, 30 metres"
#  "Shooting Men's Dueling Pistol, 30 metres, Team"
#  "Lacrosse Men's Lacrosse"
#  "Gymnastics Men's Individual All-Around, 4 Events"
#  "Gymnastics Men's Club Swinging" "Gymnastics Men's Side Horse"
#  "Snowboarding Women's Giant Slalom"
#  "Shooting Men's Military Pistol, Team" "Skeleton Women's Skeleton"
#  "Jeu De Paume Men's Singles" "Fencing Men's Single Sticks, Individual"
#  "Snowboarding Men's Parallel Giant Slalom" "Gymnastics Men's Tumbling"
#  "Snowboarding Men's Slopestyle" 'Luge Mixed Team Relay'
#  "Swimming Men's 100 Yard Backstroke"
#  "Swimming Men's 440 Yard Breaststroke" "Athletics Men's 4 mile, Team"
#  "Canoeing Men's Canadian Singles, 10,000 metres"
#  "Ski Jumping Women's Normal Hill, Individual"
#  "Swimming Men's 200 metres Obstacle Course"
#  "Freestyle Skiing Women's Slopestyle"
#  "Shooting Men's Small-Bore Rifle, Disappearing Target, 25 metres, Team"
#  "Swimming Men's 400 metres Breaststroke" "Archery Women's Team Round"
#  "Cycling Men's 25 kilometres" "Athletics Men's 4,000 metres Steeplechase"
#  "Athletics Men's Shot Put, Both Hands"
#  "Athletics Men's 2,500 metres Steeplechase"
#  "Weightlifting Men's All-Around Dumbbell Contest"
#  "Freestyle Skiing Men's Ski Cross" "Snowboarding Men's Parallel Slalom"
#  "Archery Men's Continental Style" "Athletics Men's Pentathlon (Ancient)"
#  "Fencing Men's Sabre, Masters, Individual" "Athletics Men's Stone Throw"
#  'Sailing Mixed 20+ Ton' "Swimming Men's 1,200 metres Freestyle"
#  "Shooting Men's Small-Bore Rifle, Disappearing Target, 25 yards"
#  "Shooting Men's Small-Bore Rifle, Moving Target, 25 yards"
#  "Athletics Men's Javelin Throw, Freestyle" 'Sailing Mixed 12 metres'
#  'Sailing Mixed 10 metres' "Military Ski Patrol Men's Military Ski Patrol"
#  "Athletics Men's Javelin Throw, Both Hands"
#  "Shooting Men's Running Target, Single And Double Shot"
#  "Speed Skating Men's Allround" 'Sailing Mixed 7 metres'
#  "Gymnastics Men's Individual All-Around, 5 Events"
#  "Shooting Men's Free Rifle, Any Position, 300 metres"
#  "Shooting Men's Military Rifle, 1873-1874 Gras Model, Kneeling Or Standing, 200 metres"
#  "Shooting Men's Military Rifle, Kneeling Or Standing, 300 metres"
#  "Shooting Men's Military Revolver, 20 metres"
#  'Art Competitions Mixed Music, Instrumental And Chamber'
#  'Art Competitions Mixed Unknown Event'
#  "Canoeing Men's Kayak Doubles, 200 metres" 'Sailing Mixed 1-2 Ton'
#  'Equestrianism Mixed Hacks And Hunter Combined' "Cricket Men's Cricket"
#  'Sailing Mixed 0.5-1 Ton' 'Croquet Mixed Singles, One Ball'
#  'Croquet Mixed Doubles'
#  "Fencing Men's epee, Masters and Amateurs, Individual"
#  "Equestrianism Men's Vaulting, Individual"
#  "Archery Men's Au Cordon Dore, 50 metres"
#  "Swimming Men's 200 metres Team Swimming" 'Sailing Mixed 10-20 Ton'
#  'Croquet Mixed Singles, Two Balls' 'Sailing Mixed 2-3 Ton'
#  "Shooting Men's Small-Bore Rifle, Prone, 50 and 100 yards"
#  "Shooting Men's Small-Bore Rifle, 50 and 100 yards, Team"
#  "Archery Men's Target Archery, 33 metres, Individual"
#  "Archery Men's Target Archery, 50 metres, Individual"
#  "Archery Men's Target Archery, 33 metres, Team"
#  "Archery Men's Target Archery, 50 metres, Team" 'Sailing Mixed 0-0.5 Ton'
#  "Athletics Men's 5,000 metres, Team" "Equestrianism Men's Vaulting, Team"
#  'Equestrianism Mixed Four-In-Hand Competition'
#  "Shooting Men's Dueling Pistol Au Commandement, 25 metres"
#  "Shooting Men's Free Pistol, 25 metres"
#  "Shooting Men's Military Revolver, 1873-1874 Gras Model, 20 metres"
#  "Shooting Men's Dueling Pistol Au Vise 20 metres"
#  "Shooting Men's Trap, Single Shot, 16 metres"
#  "Shooting Men's Trap, Double Shot, 14 metres"
#  'Equestrianism Mixed Long Jump' "Cycling Men's 333 metres Time Trial"
#  "Cycling Men's 10,000 metres" "Swimming Men's 1,000 metres Freestyle"
#  'Equestrianism Mixed High Jump' "Tennis Men's Doubles, Covered Courts"
#  "Archery Men's Sur La Perche a La Pyramide"
#  "Archery Men's Au Chapelet, 50 metres"
#  "Archery Men's Championnat Du Monde"
#  "Archery Men's Au Chapelet, 33 metres"
#  "Archery Men's Au Cordon Dore, 33 metres"
#  "Archery Men's Target Archery, 28 metres, Individual"
#  "Archery Men's Sur La Perche a La Herse"
#  'Motorboating Mixed A-Class (Open)'
#  "Basque Pelota Men's Two-Man Teams With Cesta"
#  "Rowing Men's 6-Man Naval Rowing Boats"
#  'Art Competitions Mixed Music, Vocals'
#  "Rowing Men's 17-Man Naval Rowing Boats"
#  'Art Competitions Mixed Music, Unknown Event'
#  'Art Competitions Mixed Sculpturing, Medals And Plaques'
#  'Art Competitions Mixed Sculpturing, Medals'
#  'Art Competitions Mixed Sculpturing, Reliefs'
#  "Figure Skating Men's Special Figures"
#  "Swimming Men's 100 metres Freestyle For Sailors"
#  "Gymnastics Men's Parallel Bars, Teams"
#  "Swimming Men's 500 metres Freestyle"
#  "Wrestling Men's Unlimited Class, Greco-Roman"
#  "Cycling Men's 12-Hours Race" "Gymnastics Men's Horizontal Bar, Teams"
#  'Alpinism Mixed Alpinism'
#  "Archery Men's Pole Archery, Small Birds, Individual"
#  "Archery Men's Pole Archery, Large Birds, Individual"
#  "Archery Men's Pole Archery, Small Birds, Team"
#  "Archery Men's Pole Archery, Large Birds, Team"
#  'Aeronautics Mixed Aeronautics' 'Sailing Mixed 40 metres'
#  'Sailing Mixed 30 metres' "Racquets Men's Singles"
#  "Racquets Men's Doubles" 'Motorboating Mixed B-Class (Under 60 Feet)'
#  'Motorboating Mixed C-Class' 'Sailing Mixed 18 foot'] | 765
# ---------------
#
# ['China' 'Denmark' 'Netherlands' 'USA' 'Finland' 'Norway' 'Romania'
#  'Estonia' 'France' 'Morocco' 'Spain' 'Egypt' 'Iran' 'Bulgaria' 'Italy'
#  'Chad' 'Azerbaijan' 'Sudan' 'Russia' 'Argentina' 'Cuba' 'Belarus'
#  'Greece' 'Cameroon' 'Turkey' 'Chile' 'Mexico' 'Nicaragua' 'Hungary'
#  'Nigeria' 'Algeria' 'Kuwait' 'Bahrain' 'Pakistan' 'Iraq' 'Syria'
#  'Lebanon' 'Qatar' 'Malaysia' 'Germany' 'Canada' 'Ireland' 'Australia'
#  'South Africa' 'Eritrea' 'Tanzania' 'Jordan' 'Tunisia' 'Libya' 'Belgium'
#  'Djibouti' 'Palestine' 'Comoros' 'Kazakhstan' 'Brunei' 'India'
#  'Saudi Arabia' 'Maldives' 'Ethiopia' 'United Arab Emirates' 'Yemen'
#  'Indonesia' 'Philippines' 'Uzbekistan' 'Kyrgyzstan' 'Tajikistan' 'Japan'
#  'Republic of Congo' 'Switzerland' 'Brazil' 'Monaco' 'Israel' 'Uruguay'
#  'Sweden' 'Virgin Islands, US' 'Sri Lanka' 'Armenia' 'Ivory Coast' 'Kenya'
#  'Benin' 'Ukraine' 'UK' 'Ghana' 'Somalia' 'Latvia' 'Niger' 'Mali'
#  'Afghanistan' 'Poland' 'Costa Rica' 'Panama' 'Georgia' 'Slovenia'
#  'Croatia' 'Guyana' 'New Zealand' 'Portugal' 'Paraguay' 'Angola'
#  'Venezuela' 'Colombia' 'Bangladesh' 'Peru' 'El Salvador' 'Puerto Rico'
#  'Uganda' 'Honduras' 'Ecuador' 'Turkmenistan' 'Mauritius' 'Seychelles'
#  'Czech Republic' 'Luxembourg' 'Mauritania' 'Saint Kitts' 'Trinidad'
#  'Dominican Republic' 'Saint Vincent' 'Jamaica' 'Liberia' 'Suriname'
#  'Nepal' 'Mongolia' 'Austria' 'Palau' 'Lithuania' 'Togo' 'Namibia'
#  'Curacao' 'Iceland' 'American Samoa' 'Samoa' 'Rwanda' 'Dominica' 'Haiti'
#  'Malta' 'Cyprus' 'Guinea' 'Belize' 'South Korea' 'Thailand' 'Bermuda'
#  'Serbia' 'Sierra Leone' 'Papua New Guinea' 'Individual Olympic Athletes'
#  'Oman' 'Fiji' 'Vanuatu' 'Moldova' 'Bahamas' 'Guatemala'
#  'Virgin Islands, British' 'Mozambique' 'Central African Republic'
#  'Madagascar' 'Bosnia and Herzegovina' 'Guam' 'Cayman Islands' 'Slovakia'
#  'Barbados' 'Guinea-Bissau' 'Timor-Leste'
#  'Democratic Republic of the Congo' 'Gabon' 'San Marino' 'Laos' 'Botswana'
#  nan 'Cambodia' 'North Korea' 'Solomon Islands' 'Senegal' 'Cape Verde'
#  'Equatorial Guinea' 'Boliva' 'Andorra' 'Antigua' 'Zimbabwe' 'Grenada'
#  'Saint Lucia' 'Micronesia' 'Myanmar' 'Malawi' 'Zambia' 'Taiwan'
#  'Sao Tome and Principe' 'Macedonia' 'Tonga' 'Liechtenstein' 'Montenegro'
#  'Gambia' 'Cook Islands' 'Albania' 'Swaziland' 'Burkina Faso' 'Burundi'
#  'Aruba' 'Nauru' 'Vietnam' 'Bhutan' 'Marshall Islands' 'Kiribati' 'Kosovo'
#  'South Sudan' 'Lesotho'] | 206
# ---------------
#
# [nan 'Silver' 'Bronze' 'Gold'] | 4
# ---------------

# %%
# which region has highest Gold Medal | region-wise distribution of Medals

# df_medal = df_final.groupby(['region','Medal'], as_index=False)['Medal'].count()
# print(df_medal.sort_values(['Medal'], ascending=False).head(20))

df_final.groupby(['region','Medal'])['Medal'].count().sort_values(ascending = False).to_frame(name ='Medal Count').reset_index()
# Out:
#           region   Medal  Medal Count
# 0            USA    Gold         2638
# 1            USA  Silver         1641
# 2         Russia    Gold         1599
# 3            USA  Bronze         1358
# 4        Germany    Gold         1301
# ..           ...     ...          ...
# 322        Tonga  Silver            1
# 323      Ecuador    Gold            1
# 324      Senegal  Silver            1
# 325  Ivory Coast  Silver            1
# 326         Peru    Gold            1
#
# [327 rows x 3 columns]

# %%
# gender distribution

df_final.groupby(['Sex'])['ID'].count().sort_values(ascending = False).to_frame(name ='Population').reset_index()
# Out:
#   Sex  Population
# 0   M      196374
# 1   F       74393

# %%
# initial explorations | some of the stats you are looking at

df_final[['Age','Height','Weight']].describe()
# Out:
#                  Age         Height         Weight
# count  261305.000000  210684.000000  207982.000000
# mean       25.559783     175.344250      70.709523
# std         6.392501      10.519556      14.350094
# min        10.000000     127.000000      25.000000
# 25%        21.000000     168.000000      60.000000
# 50%        24.000000     175.000000      70.000000
# 75%        28.000000     183.000000      79.000000
# max        97.000000     226.000000     214.000000

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270767 entries, 0 to 270766
# Data columns (total 17 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      270767 non-null  int64
#  1   Name    270767 non-null  object
#  2   Sex     270767 non-null  object
#  3   Age     261305 non-null  float64
#  4   Height  210684 non-null  float64
#  5   Weight  207982 non-null  float64
#  6   Team    270767 non-null  object
#  7   NOC     270767 non-null  object
#  8   Games   270767 non-null  object
#  9   Year    270767 non-null  int64
#  10  Season  270767 non-null  object
#  11  City    270767 non-null  object
#  12  Sport   270767 non-null  object
#  13  Event   270767 non-null  object
#  14  Medal   39774 non-null   object
#  15  region  270746 non-null  object
#  16  notes   5039 non-null    object
# dtypes: float64(3), int64(2), object(12)
# memory usage: 35.1+ MB

# %%
# <!-- Note : copy-paste from the above -->
## Step 2: Develop Project Proposal | In this step, you will need to include the following:

## 1. Description
## Write a 5-6 sentence paragraph describing your project; include who might be interested to learn about your findings. Who might be your audience?



## 2. Questions
## Create 2-3 questions that you want to answer with the data:



## 3. Hypothesis
## What are your initial hypotheses about the data?
## Write 2-3 assumptions about the data that you'll want to go back to prove or disprove. You will want to keep them in front of you as you look at the data to keep them or change them. You may see relationships that you want to explore and will develop a "belief" about the data.  
##    Start documenting what you think you can tell from the data. 
##    What pops up as interesting to you? Most likely it will be interesting to others as well.
##    Use the discussion boards to discuss with others about your client and the data to brainstorm together.


## 4. Approach
## Describe in 5-6 sentences what approach you are going to take in order to prove (or disprove) your hypotheses. Think about the following in your answer:  
##    What features (fields/columns) are you going to look at first?
##    Is there a relationship that exists that you want to explore?
##    What metric/ evaluation measure will you use?

# %%
# <!-- Description | Write a 5-6 sentence paragraph describing your project; include who might be interested to learn about your findings. Who might be your audience?-->

# This project is an analysis of Olympics dataset, here we try to analyze performance of athletes, which countries are dominating in olympics,
# which sports is the strength or weakness of different regions. The target audience is athelets, sports organization of nation, fans, marketing agencies,
# brands which are investing in olympics for their marketing

# %%
# <!-- Questions | Create 2-3 questions that you want to answer with the data -->
# Q-1 Which are the best performing athelets in their sports ?
# Q-2 best performing nations, in which sports categories they are dominating, best atheletes belongs to which nations ?
# Q-3 demography (age-distribution) and gender participation, sports-wise gender distribution, nation-wise gender distributions ?

# %%
# <!-- Hypothesis | What are your initial hypotheses about the data? -->

# 1- Gender distribution, participation of Female should have increased over the years
# 2- China has the highest gold medal count
# 3-

# %%
# <!-- Approach | Describe in 5-6 sentences what approach you are going to take in order to prove (or disprove) your hypotheses -->

# 1- for gender participation analysis over the years, I am going to take the gender column and count their number over the years
# then I will use a graphical representation of the data to see the variation in the data

# 2- to understand the best performing nation I am going to use the nation and count of different medlas they secured over the years, 
# then plot a bar chart for comparison of different nations
